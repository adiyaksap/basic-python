# %% [markdown]
# <a href="https://colab.research.google.com/github/adiyaksap/basic-python/blob/main/Data_Keuangan_Digital_Experiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Insert Data**

# %%
## Mengambil Data csv SPIP Desember dan import add ons
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn


df = pd.read_csv('/content/drive/MyDrive/Nyoba_Data/Rangkuman Data Digital Finance_Des.csv',sep = ';',index_col = 0)
display(df)
# Out:
#             Jumlah Instrumen Kartu ATM per Unit  \
# Waktu
# 01/01/2018                              167.325
# 01/02/2018                              170.033
# 01/03/2018                              172.747
# 01/04/2018                              175.221
# 01/05/2018                              180.136
# ...                                         ...
# 01/07/2023                              274.116
# 01/08/2023                              277.879
# 01/09/2023                              281.348
# 01/10/2023                              284.697
# 01/11/2023                              282.135
#
#             Jumlah Instrumen Uang Elektronik per Unit  \
# Waktu
# 01/01/2018                                     97.164
# 01/02/2018                                    103.707
# 01/03/2018                                    109.776
# 01/04/2018                                    113.838
# 01/05/2018                                    118.651
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 71 entries, 01/01/2018 to 01/11/2023
# Data columns (total 4 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Jumlah Instrumen Kartu ATM per Unit        71 non-null     float64
#  1   Jumlah Instrumen Uang Elektronik per Unit  71 non-null     float64
#  2   Volume Transaksi  Kartu ATM                71 non-null     float64
#  3   Volume Transaksi  Uang Elektronik          71 non-null     float64
# dtypes: float64(4)
# memory usage: 2.8+ KB

# %%
df.describe()
# Out:
#        Jumlah Instrumen Kartu ATM per Unit  \
# count                            71.000000
# mean                            211.413746
# std                              37.610798
# min                             159.395000
# 25%                             176.618000
# 50%                             213.409000
# 75%                             240.005500
# max                             284.697000
#
#        Jumlah Instrumen Uang Elektronik per Unit  Volume Transaksi  Kartu ATM  \
# count                                  71.000000                    71.000000
# mean                                  453.473606                589214.539437
# std                                   250.685458                 49234.818061
# min                                    97.164000                459583.245000
# 25%                                   221.120500                558238.835000
# 50%                                   432.281000                594284.910000
# ...

# %% [markdown]
# ##**Mengetahui Jumlah Instrumen Dari Masing-Masing Alat Pembayaran**

# %%
import datetime
from pandas_datareader.data import DataReader

plt.style.use('ggplot')

plt.subplot(121)
df['Jumlah Instrumen Kartu ATM per Unit'].plot(kind='line',figsize=(50,10),color='red',linewidth=3,marker='x')
plt.title('Jumlah Kartu ATM Beredar Di Indonesia per Unit Periode 2018 - 2023',size=30,weight='bold')
plt.xlabel('Periode',size=15)
plt.ylabel('Unit',size=15)
plt.legend()

plt.subplot(122)
df['Jumlah Instrumen Uang Elektronik per Unit'].plot(kind='line',figsize=(50,10),color='blue',linewidth=3,marker='x')
plt.title('Jumlah Uang Elektronik Beredar Di Indonesia per Unit Periode 2018 - 2023',size=30,weight='bold')
plt.xlabel('Periode',size=15)
plt.ylabel('Unit',size=15)
plt.legend()


plt.show()
plt.savefig('jumlahunit.jpg')

# %% [markdown]
# #**Mengetahui Volume Transaksi Dari Masing-Masing Alat Pembayaran**

# %%
import datetime
from pandas_datareader.data import DataReader

plt.style.use('fivethirtyeight')

plt.subplot(121)
df['Volume Transaksi  Kartu ATM'].plot(kind='line',figsize=(50,10),color='red',linewidth=3,marker='x')
plt.title('Volume Transaksi Kartu ATM Di Indonesia Periode 2018 - 2023',size=30,weight='bold')
plt.xlabel('Periode',size=15)
plt.ylabel('Volume (Rp)',size=15)
plt.legend()

plt.subplot(122)
df['Volume Transaksi  Uang Elektronik'].plot(kind='line',figsize=(50,10),color='blue',linewidth=3,marker='x')
plt.title('Volume Transaksi Uang Elektronik Beredar Di Indonesia Periode 2018 - 2023',size=30,weight='bold')
plt.xlabel('Periode',size=15)
plt.ylabel('Volume (Rp)',size=15)
plt.legend()


plt.show()
plt.savefig('volumetransaksi.jpg')
