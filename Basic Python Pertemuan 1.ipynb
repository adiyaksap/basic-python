# %%
print ("Hello, World!")
# Out:
# Hello, World!

# %%
#variabel
salam = "Selamat Sore!"
print(salam)
# Out:
# Selamat Sore!

# %%
#print sep dan end
print("Budi", 123, ".")
# Out:
# Budi 123 .

# %%
print("Budi", 123, ".", sep=" ")
# Out:
# Budi 123 .

# %%
print("Budi", 123, ".", sep="-")
# Out:
# Budi-123-.

# %%
print("Halo selamat pagi!", end="-")
print("Saya ingin jadi AI Profesional!")
# Out:
# Halo selamat pagi!-Saya ingin jadi AI Profesional!

# %%
#ini untuk sapaan
menyapa = "Halo!"
print(menyapa)
# Out:
# Halo!

# %% [markdown]
# ## Tipe Data

# %%
#tipe data number
#integer
integer = 100
print(integer)
# Out:
# 100

# %%
#float
float = 0.5
print(float)
# Out:
# 0.5

# %%
#complex 
comp = 1+3j
print(comp)
# Out:
# (1+3j)

# %%
print(type(integer))
print(type(float))
print(type(comp))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
#tipe data string
string = "Indonesia"
print(type(string))
# Out:
# <class 'str'>

# %%
boolean = true
print(boolean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-c6d58ec37c5b> in <module>
# ----> 1 boolean = true
#       2 print(boolean)
#
# NameError: name 'true' is not defined

# %%
num = 0 
print(bool(num))
# Out:
# False

# %%
num = 1 
print(bool(num))
# Out:
# True

# %% [markdown]
# ##Operasi dasar

# %%
num_satu = 2 
num_dua = 1
number = num_satu + num_dua
print(number)
# Out:
# 3

# %%
x = 29
y = 4.5
pengurangan = x-y
print(pengurangan)
# Out:
# 24.5

# %%
x = 19
y = 98
multiple = x*y
print(multiple)
# Out:
# 1862

# %%
x = 'ha'
print(x*7)
# Out:
# hahahahahahaha

# %%
x = 15
y = 2
bagi = x/y
print(bagi)
# Out:
# 7.5

# %%
x = 15
y = 2
bagi = x//y
print(bagi)
# Out:
# 7

# %%
x = 9
y = 2
modulus = x % y
print(modulus)
# Out:
# 1

# %%
x = 5
exponent = x ** 6
print(exponent)
# Out:
# 15625

# %% [markdown]
# ## Operator Penugasan

# %%
x = "Halo"
print(x)
# Out:
# Halo

# %%
x = 4
x += 5
print(x)
# Out:
# 9

# %%
x = 5
x -= 6
print(x)
# Out:
# -1

# %%
x = 15
x /= 46
print(x)
# Out:
# 0.32608695652173914

# %%
x = 16
x *= 45
print(x)
# Out:
# 720

# %% [markdown]
# #operator perbandingan

# %%
x = 4
y = 7
hasil = x > y 
print(hasil)
# Out:
# False

# %%
x = 4
y = 7
hasil = x < y 
print(hasil)
# Out:
# True

# %%
hasil2 = x == y
print(hasil2)
# Out:
# False
